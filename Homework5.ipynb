# %% [markdown]
# Попробуйте обучить нейронную сеть LSTM на любом другом датасете (любимый временной ряд, текст на русском (другом языке) как генератор или классификатор, или прилагаемый набор airline-passengers - пасажиропоток для авиалиний). Опишите, какой результата вы получили? Что помогло вам улучшить ее точность?

# %%
import tensorflow as tf
tf.version.VERSION
# Out:
# '2.9.0-dev20220318'

# %%
x = tf.random.uniform([3, 3])

print("есть ли доступные GPU: "),
print(tf.config.list_physical_devices("GPU"))

print("тензор на GPU #0:  "),
print(x.device.endswith('GPU:0'))
# Out:
# есть ли доступные GPU:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# тензор на GPU #0:
# False

# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN, LSTM, GRU
from keras.models import Sequential


# Сейчас попробуем наделить машинный дух просветлением. Если меня долбанёт молния - в моей смерти вините Небесную Канцелярию =) 
with open("chuantzu.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("ascii", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)


# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выберете фиксированную длину последовательность 10 символов 
SEQLEN, STEP = 10, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 128, 128
NUM_ITERATIONS = 25 # 25 должно быть достаточно
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100

'''
Создание очень простой рекуррентной нейронной сети. В ней будет один реккурентный закодированный входной слой. За ним последует полносвязный слой связанный с набором возможных следующих символов, которые конвертированы в вероятностные результаты через стандартную softmax активацию с multi-class cross-encoding loss функцию ссылающуются на предсказание one-hot encoding лейбл символа
'''

model = Sequential()
model.add(
    LSTM(  # GRU, LSTM, SimpleRNN
        HIDDEN_SIZE,
        return_sequences=False,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")


# выполнение серий тренировочных и демонстрационных итераций 
for iteration in range(NUM_ITERATIONS):

    # для каждой итерации запуск передачи данных в модель 
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру 
        print(y_pred, end="")

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# C:\Users\NitroPC\AppData\Local\Temp/ipykernel_15552/3568931301.py:39: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
# C:\Users\NitroPC\AppData\Local\Temp/ipykernel_15552/3568931301.py:40: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
# ==================================================
# Итерация #: 0
# 4256/4256 [==============================] - 121s 28ms/step - loss: 2.0979
# Генерация из посева:  was calle
#  was called the world the way of the way of the way of the way of the way of the way of the way of the way of ==================================================
# Итерация #: 1
# 4256/4256 [==============================] - 119s 28ms/step - loss: 1.6815
# Генерация из посева:  middle of
#  middle of the way and the sage of the sage of the sage of the sage of the sage of the sage of the sage of the==================================================
# Итерация #: 2
# 4256/4256 [==============================] - 124s 29ms/step - loss: 1.5423
# Генерация из посева: . he who h
# . he who has no be a state of the world and the way of the world and the way of the world and the way of the w==================================================
# Итерация #: 3
# 4256/4256 [==============================] - 125s 29ms/step - loss: 1.4658
# Генерация из посева: d bad men
# d bad men with the sage and said, "i have no master the sage and said, "i have no master the sage and said, "i==================================================
# Итерация #: 4
# 4256/4256 [==============================] - 125s 29ms/step - loss: 1.4149
# Генерация из посева: d to be ca
# d to be called the sage to the sage to the sage to the sage to the sage to the sage to the sage to the sage to==================================================
# Итерация #: 5
# 4256/4256 [==============================] - 127s 30ms/step - loss: 1.3780
# Генерация из посева: ion of rig
# ion of right and state of the way of the way of the way of the way of the way of the way of the way of the way==================================================
# Итерация #: 6
# 4256/4256 [==============================] - 130s 31ms/step - loss: 1.3495
# Генерация из посева: y. it has
# y. it has no more that they will not be a man of the state of the world with the sage and shun and still he ha==================================================
# Итерация #: 7
# 4256/4256 [==============================] - 132s 31ms/step - loss: 1.3259
# Генерация из посева:  never tou
#  never touster the sage the way of the way of the way of the way of the way of the way of the way of the way o==================================================
# Итерация #: 8
# 4256/4256 [==============================] - 137s 32ms/step - loss: 1.3073
# Генерация из посева: ? he who t
# ? he who tried to the world and the world and the world and the world and the world and the world and the worl==================================================
# Итерация #: 9
# 4256/4256 [==============================] - 138s 33ms/step - loss: 1.2914
# Генерация из посева: e that is
# e that is the way of the world is the way of the world is the way of the world is the way of the world is the ==================================================
# Итерация #: 10
# 4256/4256 [==============================] - 143s 34ms/step - loss: 1.2771
# Генерация из посева:  lay in su
#  lay in such a thousand things are the way of the world there is a man of the world there is a man of the worl==================================================
# Итерация #: 11
# 4256/4256 [==============================] - 142s 33ms/step - loss: 1.2653
# Генерация из посева: m. it fill
# m. it filled with the world and the world and the world and the world and the world and the world and the worl==================================================
# Итерация #: 12
# 4256/4256 [==============================] - 142s 33ms/step - loss: 1.2539
# Генерация из посева:  lord. sup
#  lord. superiors and said, "i was the sage is the sage is the sage is the sage is the sage is the sage is the ==================================================
# Итерация #: 13
# 4256/4256 [==============================] - 146s 34ms/step - loss: 1.2448
# Генерация из посева: honor your
# honor your mind the way is the way they will never be considered the way is the way they will never be conside==================================================
# Итерация #: 14
# 4256/4256 [==============================] - 150s 35ms/step - loss: 1.2360
# Генерация из посева: et the fiv
# et the five of the world will be a man who has been the world will be a man who has been the world will be a m==================================================
# Итерация #: 15
# 4256/4256 [==============================] - 154s 36ms/step - loss: 1.2284
# Генерация из посева: in possess
# in possession of the world, the source of the world, the source of the world, the source of the world, the sou==================================================
# Итерация #: 16
# 4256/4256 [==============================] - 156s 37ms/step - loss: 1.2207
# Генерация из посева: r calves,
# r calves, the sage said, "i have heard that the sage said, "i have heard that the sage said, "i have heard tha==================================================
# Итерация #: 17
# 4256/4256 [==============================] - 158s 37ms/step - loss: 1.2144
# Генерация из посева: if i try t
# if i try to accept the way to the sage is the state of the state of the state of the state of the state of the==================================================
# Итерация #: 18
# 4256/4256 [==============================] - 161s 38ms/step - loss: 1.2082
# Генерация из посева: ake pleasu
# ake pleasure the same the way of the same the way of the same the way of the same the way of the same the way ==================================================
# Итерация #: 19
# 4256/4256 [==============================] - 162s 38ms/step - loss: 1.2028
# Генерация из посева: h you inst
# h you instead of the way of heaven and earth and the world will be a son of heaven and earth and the world wil==================================================
# Итерация #: 20
# 4256/4256 [==============================] - 165s 39ms/step - loss: 1.1970
# Генерация из посева:  arc it, i
#  arc it, i don't know why it is the way and yet they were all the way and yet they were all the way and yet th==================================================
# Итерация #: 21
# 4256/4256 [==============================] - 167s 39ms/step - loss: 1.1921
# Генерация из посева: is degree,
# is degree, and then who is the way is called the world will be a five an answer and the world will be a five a==================================================
# Итерация #: 22
# 4256/4256 [==============================] - 170s 40ms/step - loss: 1.1874
# Генерация из посева: rom this t
# rom this the way of the sage is the sage is the sage is the sage is the sage is the sage is the sage is the sa==================================================
# Итерация #: 23
# 4256/4256 [==============================] - 171s 40ms/step - loss: 1.1832
# Генерация из посева: nlightenme
# nlightenments and the world will be a man has no more than the way is the way they are a man like this was the==================================================
# Итерация #: 24
# 4256/4256 [==============================] - 174s 41ms/step - loss: 1.1788
# Генерация из посева: k." hui tz
# k." hui tzu said, "i have heard that the sage is the sage is the sage is the sage is the sage is the sage is t

# %% [markdown]
# В таком варианте сеть быстро сваливается в цикл слов, замыкающийся на самом себе.

# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN, LSTM, GRU
from keras.models import Sequential


with open("chuantzu.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("ascii", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)


# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выберете фиксированную длину последовательность 10 символов 
SEQLEN, STEP = 10, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 128, 128
NUM_ITERATIONS = 25 # 25 должно быть достаточно
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100


model = Sequential()
model.add(
    LSTM(  # GRU, LSTM, SimpleRNN
        HIDDEN_SIZE,
        return_sequences=True,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(
    LSTM(  # GRU, LSTM, SimpleRNN
        HIDDEN_SIZE,
        return_sequences=False,
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")


# выполнение серий тренировочных и демонстрационных итераций 
for iteration in range(NUM_ITERATIONS):

    # для каждой итерации запуск передачи данных в модель 
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру 
        print(y_pred, end="")

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# C:\Users\NitroPC\AppData\Local\Temp/ipykernel_7112/1052807665.py:38: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
# C:\Users\NitroPC\AppData\Local\Temp/ipykernel_7112/1052807665.py:39: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
# ==================================================
# Итерация #: 0
# 4256/4256 [==============================] - 249s 56ms/step - loss: 2.0109
# Генерация из посева: no sound,
# no sound, the world in the world in the world in the world in the world in the world in the world in the world==================================================
# Итерация #: 1
# 4256/4256 [==============================] - 199s 47ms/step - loss: 1.5499
# Генерация из посева: e cicada,
# e cicada, the sage the sage the sage the sage the sage the sage the sage the sage the sage the sage the sage t==================================================
# Итерация #: 2
# 4256/4256 [==============================] - 223s 52ms/step - loss: 1.4175
# Генерация из посева: ved, so th
# ved, so that is the sage the way is the sage the way is the sage the way is the sage the way is the sage the w==================================================
# Итерация #: 3
# 4256/4256 [==============================] - 219s 51ms/step - loss: 1.3454
# Генерация из посева: thousand l
# thousand li said, "i have heard the sage the sage the sage the sage the sage the sage the sage the sage the sa==================================================
# Итерация #: 4
# 4256/4256 [==============================] - 216s 51ms/step - loss: 1.2982
# Генерация из посева: bugs can a
# bugs can a man who had a man who had a man who had a man who had a man who had a man who had a man who had a m==================================================
# Итерация #: 5
# 4256/4256 [==============================] - 213s 50ms/step - loss: 1.2620
# Генерация из посева: he haunche
# he haunched and said, "i have no sound of the way of the way of the way of the way of the way of the way of th==================================================
# Итерация #: 6
# 4256/4256 [==============================] - 216s 51ms/step - loss: 1.2344
# Генерация из посева: who are sh
# who are should he have heard the world will be a great sight of the world will be a great sight of the world w==================================================
# Итерация #: 7
# 4256/4256 [==============================] - 219s 51ms/step - loss: 1.2110
# Генерация из посева: you're bet
# you're better the world and shun and said, "i have heard that is what is so many saw the world and shun and sa==================================================
# Итерация #: 8
# 4256/4256 [==============================] - 218s 51ms/step - loss: 1.1912
# Генерация из посева: things wit
# things with the way is the way of the way of the way of the way of the way of the way of the way of the way of==================================================
# Итерация #: 9
# 4256/4256 [==============================] - 219s 52ms/step - loss: 1.1736
# Генерация из посева:  broad and
#  broad and still he had the way of the world will be a calling the world will be a calling the world will be a==================================================
# Итерация #: 10
# 4256/4256 [==============================] - 219s 51ms/step - loss: 1.1578
# Генерация из посева: y forgiven
# y forgiven, the man of the world with the world with the world with the world with the world with the world wi==================================================
# Итерация #: 11
# 4256/4256 [==============================] - 216s 51ms/step - loss: 1.1439
# Генерация из посева: t was my n
# t was my nature of the world is the world is the world is the world is the world is the world is the world is ==================================================
# Итерация #: 12
# 4256/4256 [==============================] - 223s 52ms/step - loss: 1.1308
# Генерация из посева: not bother
# not bother to ask about the sage has no constant receive a hair out of the way of the way of the way of the wa==================================================
# Итерация #: 13
# 4256/4256 [==============================] - 219s 51ms/step - loss: 1.1188
# Генерация из посева: need to hi
# need to his face the way of the world will be able to the way of the world will be able to the way of the worl==================================================
# Итерация #: 14
# 4256/4256 [==============================] - 216s 51ms/step - loss: 1.1078
# Генерация из посева: ide ears a
# ide ears and easy wander in the world will be a great serenity and the sage had a horse and the sage had a hor==================================================
# Итерация #: 15
# 4256/4256 [==============================] - 218s 51ms/step - loss: 1.0977
# Генерация из посева: cerned. dr
# cerned. dreaming the sage is not a man who has no place to be a feudal lords and death are not a man who has n==================================================
# Итерация #: 16
# 4256/4256 [==============================] - 224s 53ms/step - loss: 1.0877
# Генерация из посева: righteousn
# righteousness and still have no longer be called a single body will be a father cannot be any ten thousand li ==================================================
# Итерация #: 17
# 4256/4256 [==============================] - 218s 51ms/step - loss: 1.0785
# Генерация из посева: ime to go
# ime to go and said, "i have heard that is not a man of ancient times who has at the same reason is the way of ==================================================
# Итерация #: 18
# 4256/4256 [==============================] - 225s 53ms/step - loss: 1.0705
# Генерация из посева: and the or
# and the ordinary person like the way of the way of the way of the way of the way of the way of the way of the ==================================================
# Итерация #: 19
# 4256/4256 [==============================] - 232s 54ms/step - loss: 1.0620
# Генерация из посева: ace after
# ace after the way and the people and the people and the people and the people and the people and the people an==================================================
# Итерация #: 20
# 4256/4256 [==============================] - 228s 54ms/step - loss: 1.0553
# Генерация из посева: wice, stra
# wice, straighten my own whole and forget the way of heaven. therefore the way of heaven. therefore the way of ==================================================
# Итерация #: 21
# 4256/4256 [==============================] - 217s 51ms/step - loss: 1.0475
# Генерация из посева: ght and so
# ght and so came to the way of man. the man of the world will be a man who has not use the way they were all th==================================================
# Итерация #: 22
# 4256/4256 [==============================] - 212s 50ms/step - loss: 1.0403
# Генерация из посева: e-this is
# e-this is the way of heaven and earth and said, "i have heard that i have no way to the world will be a great ==================================================
# Итерация #: 23
# 4256/4256 [==============================] - 221s 52ms/step - loss: 1.0344
# Генерация из посева: esire and
# esire and the way of heaven and earth are the world is the way of heaven and earth are the world is the way of==================================================
# Итерация #: 24
# 4256/4256 [==============================] - 217s 51ms/step - loss: 1.0282
# Генерация из посева: of studies
# of studies to the south success and shown the state of the state of the state of the state of the state of the

# %% [markdown]
# Добавлен ещё слой LSTM. Потери снижены с 1.17 до 1.02. Но выдача всё равно зацикливается на наиболее распространённых словах.

# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN, LSTM, GRU
from keras.models import Sequential


with open("chuantzu.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("ascii", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)


# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выберете фиксированную длину последовательность 10 символов 
SEQLEN, STEP = 10, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 128, 128
NUM_ITERATIONS = 25 # 25 должно быть достаточно
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100


model = Sequential()
model.add(
    GRU(  # GRU, LSTM, SimpleRNN
        HIDDEN_SIZE,
        return_sequences=True,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(
    GRU(  # GRU, LSTM, SimpleRNN
        HIDDEN_SIZE,
        return_sequences=False,
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")


# выполнение серий тренировочных и демонстрационных итераций 
for iteration in range(NUM_ITERATIONS):

    # для каждой итерации запуск передачи данных в модель 
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру 
        print(y_pred, end="")

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# C:\Users\NitroPC\AppData\Local\Temp/ipykernel_7112/4008607449.py:38: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
# C:\Users\NitroPC\AppData\Local\Temp/ipykernel_7112/4008607449.py:39: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
# ==================================================
# Итерация #: 0
# 4256/4256 [==============================] - 199s 45ms/step - loss: 1.8644
# Генерация из посева: ings to la
# ings to late of the sage and said, "if i have nothing the sage and said, "if i have nothing the sage and said,==================================================
# Итерация #: 1
# 4256/4256 [==============================] - 187s 44ms/step - loss: 1.5010
# Генерация из посева: tue of hea
# tue of heaven and earth of the world will be a state of the world will be a state of the world will be a state==================================================
# Итерация #: 2
# 4256/4256 [==============================] - 195s 46ms/step - loss: 1.3997
# Генерация из посева: t of the l
# t of the lord of the man of the man of the man of the man of the man of the man of the man of the man of the m==================================================
# Итерация #: 3
# 4256/4256 [==============================] - 193s 45ms/step - loss: 1.3424
# Генерация из посева: re? what a
# re? what asked the man of the world and the man of the world and the man of the world and the man of the world==================================================
# Итерация #: 4
# 4256/4256 [==============================] - 193s 45ms/step - loss: 1.3034
# Генерация из посева:  he is chi
#  he is chieh and still the three and still the three and still the three and still the three and still the thr==================================================
# Итерация #: 5
# 4256/4256 [==============================] - 193s 45ms/step - loss: 1.2742
# Генерация из посева: g of equal
# g of equality and transformation of the world and the way in the world and the way in the world and the way in==================================================
# Итерация #: 6
# 4256/4256 [==============================] - 193s 45ms/step - loss: 1.2517
# Генерация из посева: do not kno
# do not know that the man who has no man who has no man who has no man who has no man who has no man who has no==================================================
# Итерация #: 7
# 4256/4256 [==============================] - 202s 47ms/step - loss: 1.2326
# Генерация из посева: nk with wi
# nk with wind and stillness and disciples of the world will be a man of the world will be a man of the world wi==================================================
# Итерация #: 8
# 4256/4256 [==============================] - 183s 43ms/step - loss: 1.2163
# Генерация из посева:  too assid
#  too asside his state of lu said, "i would not be a company of the sage seems to the state of lu said, "i woul==================================================
# Итерация #: 9
# 4256/4256 [==============================] - 183s 43ms/step - loss: 1.2028
# Генерация из посева: ivide fail
# ivide fail to describe of the way of the way of the way of the way of the way of the way of the way of the way==================================================
# Итерация #: 10
# 4256/4256 [==============================] - 185s 43ms/step - loss: 1.1904
# Генерация из посева: h his mout
# h his mouth of the way there was not the way there was not the way there was not the way there was not the way==================================================
# Итерация #: 11
# 4256/4256 [==============================] - 185s 43ms/step - loss: 1.1783
# Генерация из посева: come flock
# come flocks of the world is a man of the way of the world is a man of the way of the world is a man of the way==================================================
# Итерация #: 12
# 4256/4256 [==============================] - 181s 43ms/step - loss: 1.1692
# Генерация из посева: ed to be a
# ed to be a stop and death and the way of the world is not the way of the world is not the way of the world is ==================================================
# Итерация #: 13
# 4256/4256 [==============================] - 183s 43ms/step - loss: 1.1601
# Генерация из посева: ing in dea
# ing in death are the same a sight of the world is not the sage is the same a sight of the world is not the sag==================================================
# Итерация #: 14
# 4256/4256 [==============================] - 185s 43ms/step - loss: 1.1523
# Генерация из посева: he great u
# he great under the sage is not a man who has no matter how the sage is not a man who has no matter how the sag==================================================
# Итерация #: 15
# 4256/4256 [==============================] - 185s 43ms/step - loss: 1.1449
# Генерация из посева: the ailing
# the ailing his mind is to be a stop to the world is the way of the world is the way of the world is the way of==================================================
# Итерация #: 16
# 4256/4256 [==============================] - 186s 44ms/step - loss: 1.1377
# Генерация из посева: eople few.
# eople few. the sage does not depend upon remaling the truth of the sage does not depend upon remaling the trut==================================================
# Итерация #: 17
# 4256/4256 [==============================] - 186s 44ms/step - loss: 1.1320
# Генерация из посева:  into ever
#  into everything that the sage does not still the ten thousand things are not the same as a sigh of the sage d==================================================
# Итерация #: 18
# 4256/4256 [==============================] - 191s 45ms/step - loss: 1.1262
# Генерация из посева: te." their
# te." their former kings and still have no way to the world will be a big robber chih was able to like this is ==================================================
# Итерация #: 19
# 4256/4256 [==============================] - 189s 44ms/step - loss: 1.1210
# Генерация из посева: rm `commun
# rm `community of the world will not stop alone and regulations of the world will not stop alone and regulation==================================================
# Итерация #: 20
# 4256/4256 [==============================] - 186s 44ms/step - loss: 1.1166
# Генерация из посева: of the way
# of the way in the midst of man can do i know that you are some other men, but i would not be a boat and death ==================================================
# Итерация #: 21
# 4256/4256 [==============================] - 192s 45ms/step - loss: 1.1115
# Генерация из посева: now murky,
# now murky, the sage does not see him and see him and see him and see him and see him and see him and see him a==================================================
# Итерация #: 22
# 4256/4256 [==============================] - 187s 44ms/step - loss: 1.1080
# Генерация из посева:  my place
#  my place and righteousness and see that the sage will be a man who has all right to the same reason it is not==================================================
# Итерация #: 23
# 4256/4256 [==============================] - 187s 44ms/step - loss: 1.1042
# Генерация из посева:  be one i
#  be one i don't know where there is nothing to be a complied to the one who does not decide the true form of t==================================================
# Итерация #: 24
# 4256/4256 [==============================] - 185s 43ms/step - loss: 1.1001
# Генерация из посева: ills and s
# ills and still haven't got it and loss is not really be any thing that is not really be any thing that is not

# %% [markdown]
# А тут взяли да и заменили LSTM на GRU - и эффект сразу заметен: генератор стал коллапсировать в самоповторы значительно реже, хотя номинально потери поднялись до 1.10.

# %% [markdown]
# Вывод: для вменяемой генерации текста сырого вывода из нейросети недостаточно. Надо добавлять алгоритм для отбора неповторяющихся последовательностей.
